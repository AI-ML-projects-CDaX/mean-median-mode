# %%
from collections import Counter

data = list(map(float, input("Enter numbers (comma separated): ").split(",")))

n = len(data)

if n == 0:
    print(" No data entered.")
    exit()

data.sort()

# Mean
mean = sum(data) / n

if n % 2 == 0:
    median = (data[n//2 - 1] + data[n//2]) / 2
else:
    median = data[n//2]

# Mode
freq = Counter(data)
max_freq = max(freq.values())
modes = [k for k, v in freq.items() if v == max_freq]

# Step 3: Display results
print("\n Statistical Measures")
print("Mean   :", round(mean, 2))
print("Median :", round(median, 2))

if len(modes) == n:
    print("Mode   : No mode (all values occur equally)")
else:
    print("Mode   :", modes)
# Out:
# Enter numbers (comma separated):  7832145
#  Statistical Measures
# Mean   : 7832145.0
# Median : 7832145.0
# Mode   : No mode (all values occur equally)
